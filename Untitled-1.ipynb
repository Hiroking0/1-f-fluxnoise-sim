# %%
from complete import *

dev = washer_device(10,5)
fig, ax = dev.plot_mesh(edge_color="k", show_sites=False,figsize=(10,5))
_ = dev.plot_polygons(ax=ax, legend=True)
plt.show()

# %%
from complete import *
plot_Bz_color(dev)
